# %%
G = nx.Graph()

# %%
G.add_node("A")

# %%
G.add_node("B")
G.add_node("C")
G.add_node("D")

# %%
G.add_edge("A","B")
G.add_edge("A","C")
G.add_edge("A","D")
G.add_edge("B","C")
G.add_edge("D","C")

# %%
nx.draw(G, with_labels = True)
